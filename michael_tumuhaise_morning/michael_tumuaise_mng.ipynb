# %%
#importing libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset/reading the dataset
df = pd.read_csv('bse_dataset5.csv')

# %%
df
# Out:
#          Timestamp What is your gender?   Age What is your emotion?  \
# 0    5/7/2023 9:38                 Male  21.0               Content
# 1    5/7/2023 9:38        Marabou stock  45.0                 Weird
# 2    5/7/2023 9:39              Female   20.0                 Happy
# 3    5/7/2023 9:39                 Male  21.0                 Happy
# 4    5/7/2023 9:39               Female  21.0                 Happy
# ..             ...                  ...   ...                   ...
# 164            NaN                  NaN   NaN                   NaN
# 165            NaN                  NaN   NaN                   NaN
# 166            NaN                  NaN   NaN                   NaN
# 167            NaN                  NaN   NaN                   NaN
# 168            NaN                  NaN   NaN                   NaN
#
#     Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
# confirm shape
df.shape
# Out:
# (169, 15)

# %%
print(df.to_string())
# Out:
#           Timestamp What is your gender?    Age What is your emotion?  Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0     5/7/2023 9:38                 Male  21.00               Content           2002               4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1     5/7/2023 9:38        Marabou stock  45.00                 Weird           2100                8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
#replace using mean, median, mode
#calculate mean
m = df['Calories'].mean()
df['Calories'].fillna(m, inplace=True)
df
# Out:
#           Timestamp What is your gender?   Age What is your emotion?  \
# 0     5/7/2023 9:38                 Male  21.0               Content
# 1     5/7/2023 9:38        Marabou stock  45.0                 Weird
# 2     5/7/2023 9:39              Female   20.0                 Happy
# 3     5/7/2023 9:39                 Male  21.0                 Happy
# 4     5/7/2023 9:39               Female  21.0                 Happy
# ..              ...                  ...   ...                   ...
# 97    5/7/2023 9:56               Female  29.0             Grateful
# 98    5/7/2023 9:59              Female   21.0             Grateful
# 99   5/7/2023 10:11                 Male  21.0                   Yes
# 100  5/7/2023 10:17              Female   21.0                   Sad
# 101  5/7/2023 10:47                 Male  21.0                   Sad
#
#     Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
df_new = df.dropna(inplace=True)
df_new

# %%
print(df.to_string())
# Out:
#           Timestamp What is your gender?    Age What is your emotion?  Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0     5/7/2023 9:38                 Male  21.00               Content           2002               4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1     5/7/2023 9:38        Marabou stock  45.00                 Weird           2100                8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
df_new = df.dropna()
df_new
# Out:
#           Timestamp What is your gender?   Age What is your emotion?  \
# 0     5/7/2023 9:38                 Male  21.0               Content
# 1     5/7/2023 9:38        Marabou stock  45.0                 Weird
# 2     5/7/2023 9:39              Female   20.0                 Happy
# 3     5/7/2023 9:39                 Male  21.0                 Happy
# 4     5/7/2023 9:39               Female  21.0                 Happy
# ..              ...                  ...   ...                   ...
# 97    5/7/2023 9:56               Female  29.0             Grateful
# 98    5/7/2023 9:59              Female   21.0             Grateful
# 99   5/7/2023 10:11                 Male  21.0                   Yes
# 100  5/7/2023 10:17              Female   21.0                   Sad
# 101  5/7/2023 10:47                 Male  21.0                   Sad
#
#     Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
df_new.fillna(100, inplace=True)
df_new
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8236\814389012.py in <module>
# ----> 1 df_new.fillna(100, inplace=True)
#       2 df_new
#
# AttributeError: 'NoneType' object has no attribute 'fillna'

# %%
df_new = df.dropna(inplace=True)
df_new

# %%
df = df.dropna(inplace=True)
df

# %%
#Empty cells, wrong formats wrong data duplicates (core of data preparation and preprocessing)
#calculate median
df = pd.read_csv('bse_dataset5.csv')
med = df['Calories'].median()
df['Calories'].fillna(med, inplace=True)

# %%
print(med)
# Out:
# 318.6

# %%
df
# Out:
#           Timestamp What is your gender?   Age What is your emotion?  \
# 0     5/7/2023 9:38                 Male  21.0               Content
# 1     5/7/2023 9:38        Marabou stock  45.0                 Weird
# 2     5/7/2023 9:39              Female   20.0                 Happy
# 3     5/7/2023 9:39                 Male  21.0                 Happy
# 4     5/7/2023 9:39               Female  21.0                 Happy
# 5     5/7/2023 9:39               Female  23.0                Happy
# 6     5/7/2023 9:39               female  21.0            irritated
# 7     5/7/2023 9:39              Female   22.0  In a state of wonder
# 8     5/7/2023 9:39                 Male  22.0                   Sad
# 9     5/7/2023 9:39               Female  20.0                 happy
# 10    5/7/2023 9:39                 Male  24.0                 Happy
# 11    5/7/2023 9:39               Female  21.0                 Moody
# 12    5/7/2023 9:39                 Male  25.0                 Happy
# ...

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#           Timestamp What is your gender?    Age What is your emotion?  \
# 0     5/7/2023 9:38                 Male  21.00               Content
# 1     5/7/2023 9:38        Marabou stock  45.00                 Weird
# 2     5/7/2023 9:39              Female   20.00                 Happy
# 3     5/7/2023 9:39                 Male  21.00                 Happy
# 4     5/7/2023 9:39               Female  21.00                 Happy
# 5     5/7/2023 9:39               Female  23.00                Happy
# 6     5/7/2023 9:39               female  21.00            irritated
# 7     5/7/2023 9:39              Female   22.00  In a state of wonder
# 8     5/7/2023 9:39                 Male  22.00                   Sad
# 9     5/7/2023 9:39               Female  20.00                 happy
# 10    5/7/2023 9:39                 Male  24.00                 Happy
# 11    5/7/2023 9:39               Female  21.00                 Moody
# ...

# %%
# calculate mode on age Activity
df = pd.read_csv('bse_dataset5.csv')
mod = df['Age'].mode()
df['Age'].fillna(med, inplace=True)

# %%
print(mod)
# Out:
# 0    21.0
# Name: Age, dtype: float64

# %%
# 20230705 convert to 2023/07/05

# %%
df.at[1,'Timestamp'] ='5/6/2023 9:39' 
df
# Out:
#           Timestamp What is your gender?    Age What is your emotion?  \
# 0     5/7/2023 9:38                 Male   21.0               Content
# 1     5/6/2023 9:39        Marabou stock   45.0                 Weird
# 2     5/7/2023 9:39              Female    20.0                 Happy
# 3     5/7/2023 9:39                 Male   21.0                 Happy
# 4     5/7/2023 9:39               Female   21.0                 Happy
# 5     5/7/2023 9:39               Female   23.0                Happy
# 6     5/7/2023 9:39               female   21.0            irritated
# 7     5/7/2023 9:39              Female    22.0  In a state of wonder
# 8     5/7/2023 9:39                 Male   22.0                   Sad
# 9     5/7/2023 9:39               Female   20.0                 happy
# 10    5/7/2023 9:39                 Male   24.0                 Happy
# 11    5/7/2023 9:39               Female   21.0                 Moody
# ...

# %%
#wrong format Rows that have hard to analyze(NaN, )
# row 5 contained non values and we filled them
df['Timestamp'].fillna("5/7/2023 9:39", inplace=True)
df
# Out:
#           Timestamp What is your gender?    Age What is your emotion?  \
# 0     5/7/2023 9:38                 Male   21.0               Content
# 1     5/7/2023 9:38        Marabou stock   45.0                 Weird
# 2     5/7/2023 9:39              Female    20.0                 Happy
# 3     5/7/2023 9:39                 Male   21.0                 Happy
# 4     5/7/2023 9:39               Female   21.0                 Happy
# 5     5/7/2023 9:39               Female   23.0                Happy
# 6     5/7/2023 9:39               female   21.0            irritated
# 7     5/7/2023 9:39              Female    22.0  In a state of wonder
# 8     5/7/2023 9:39                 Male   22.0                   Sad
# 9     5/7/2023 9:39               Female   20.0                 happy
# 10    5/7/2023 9:39                 Male   24.0                 Happy
# 11    5/7/2023 9:39               Female   21.0                 Moody
# ...

# %%
# wrong data supposed to ve 60 but u ve 6000
for x in df.index:
    if df.loc[x, gender] == 'Marabou stock':
        df.drop(x, inplace=True)

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
#ploting
import matplotlib.pyplot as plt
df['Age'].plot(kind='hist')
# df['Age'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Frequency'>
